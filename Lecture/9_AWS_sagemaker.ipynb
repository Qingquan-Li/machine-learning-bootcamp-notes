# %% [markdown]
# # Amazon Sagemaker
# Build, train, and deploy machine learning (ML) models for any use case with fully managed infrastructure, tools, and workflows
#
# - https://aws.amazon.com/sagemaker/

# %%
from IPython.lib.display import YouTubeVideo

# %%
YouTubeVideo('pfjhNe1M2t4', width=800, height=300)

# %%
YouTubeVideo('79y4WtA-zqA', width=800, height=300)

# %%
YouTubeVideo('SUQZPb0qxw4', width=800, height=300)

# %%
YouTubeVideo('7v1-uQ0lCuQ', width=800, height=300)
